# %% [markdown]
# # Measure dataset sizes
#
# Use information from `measure_dandi.py` and `measure_openneuro.py` to estimate the total
# size of records available on DANDI hub and openneuro. Gather metadata from the Dandi API. Add to that information recordings
# scraped on iEEG.org. Clean up the records in cases where the data is nonsensical.

# %%
from dandi.dandiapi import DandiAPIClient
from tqdm import tqdm
import pandas as pd
from pathlib import Path
from sklearn.linear_model import LinearRegression

# Load up all relevant metadata from DANDI archive and aggregate it.
metadata = []
for i in tqdm(range(730)):
    dandiset_id = f"{i:06d}"

    client = DandiAPIClient()
    try:
        dandiset = client.get_dandiset(dandiset_id)
        next(dandiset.get_assets())
    except:
        #print(f"Error getting {dandiset_id}")
        continue
    
    m_ = dandiset.get_raw_metadata()
    try:
        data_format = m_['assetsSummary']['dataStandard'][0]['identifier']
    except:
        data_format = 'RRID:SCR_015242'
    
    if data_format != 'RRID:SCR_015242':
        print(data_format)

    metadata.append(
        m_
    )
# Out:
#   0%|          | 0/730 [00:00<?, ?it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000000/: {"detail":"Not found."}
#   0%|          | 1/730 [00:00<02:00,  6.04it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000001/: {"detail":"Not found."}
#   0%|          | 2/730 [00:00<01:34,  7.67it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000002/: {"detail":"Not found."}
#   2%|▏         | 14/730 [00:02<02:33,  4.67it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000014/: {"detail":"Not found."}
#   4%|▍         | 28/730 [00:05<03:33,  3.29it/s]
# RRID:SCR_016124
#   7%|▋         | 53/730 [00:10<02:13,  5.08it/s]
# RRID:SCR_016124
#   8%|▊         | 57/730 [00:11<02:18,  4.85it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000057/: {"detail":"Not found."}
#   8%|▊         | 59/730 [00:11<01:55,  5.82it/s]
# RRID:SCR_016124
#   8%|▊         | 62/730 [00:12<02:09,  5.17it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000062/: {"detail":"Not found."}
#   9%|▉         | 68/730 [00:13<01:58,  5.59it/s]
# RRID:SCR_016124
#   9%|▉         | 69/730 [00:13<01:57,  5.61it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000069/: {"detail":"Not found."}
#  10%|█         | 73/730 [00:14<01:39,  6.62it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000073/: {"detail":"Not found."}
#  10%|█         | 74/730 [00:14<01:30,  7.26it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000074/: {"detail":"Not found."}
# Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000075/: {"detail":"Not found."}
#  10%|█         | 76/730 [00:14<01:17,  8.46it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000076/: {"detail":"Not found."}
# Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000077/: {"detail":"Not found."}
#  11%|█         | 78/730 [00:14<01:11,  9.15it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000078/: {"detail":"Not found."}
# Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000079/: {"detail":"Not found."}
#  11%|█         | 80/730 [00:14<01:08,  9.48it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000080/: {"detail":"Not found."}
#  11%|█         | 81/730 [00:14<01:08,  9.54it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000081/: {"detail":"Not found."}
# Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000082/: {"detail":"Not found."}
#  11%|█▏        | 83/730 [00:15<01:07,  9.65it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000083/: {"detail":"Not found."}
# Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000084/: {"detail":"Not found."}
#  12%|█▏        | 85/730 [00:15<01:04,  9.95it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000085/: {"detail":"Not found."}
# Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000086/: {"detail":"Not found."}
#  12%|█▏        | 87/730 [00:15<01:03, 10.10it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000087/: {"detail":"Not found."}
# Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000088/: {"detail":"Not found."}
#  12%|█▏        | 89/730 [00:15<01:02, 10.22it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000089/: {"detail":"Not found."}
# Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000090/: {"detail":"Not found."}
#  12%|█▏        | 91/730 [00:15<01:02, 10.25it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000091/: {"detail":"Not found."}
# Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000092/: {"detail":"Not found."}
#  13%|█▎        | 93/730 [00:16<01:01, 10.40it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000093/: {"detail":"Not found."}
# Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/
/s]Error 401 while sending GET request to https://api.dandiarchive.org/api/dandisets/000627/: {"detail":"Authentication credentials were not provided."}
#  88%|████████▊ | 639/730 [01:29<00:16,  5.44it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000639/: {"detail":"Not found."}
#  88%|████████▊ | 641/730 [01:29<00:15,  5.83it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000641/: {"detail":"Not found."}
#  88%|████████▊ | 642/730 [01:29<00:13,  6.43it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000642/: {"detail":"Not found."}
# Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000643/: {"detail":"Not found."}
#  88%|████████▊ | 644/730 [01:29<00:11,  7.60it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000644/: {"detail":"Not found."}
# Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000645/: {"detail":"Not found."}
#  88%|████████▊ | 646/730 [01:29<00:09,  8.41it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000646/: {"detail":"Not found."}
#  89%|████████▊ | 647/730 [01:30<00:09,  8.66it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000647/: {"detail":"Not found."}
# Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000648/: {"detail":"Not found."}
#  89%|████████▉ | 649/730 [01:30<00:08,  9.21it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000649/: {"detail":"Not found."}
# Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000650/: {"detail":"Not found."}
#  89%|████████▉ | 651/730 [01:30<00:08,  9.50it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000651/: {"detail":"Not found."}
# Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000652/: {"detail":"Not found."}
#  89%|████████▉ | 653/730 [01:30<00:08,  9.53it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000653/: {"detail":"Not found."}
# Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000654/: {"detail":"Not found."}
#  90%|████████▉ | 655/730 [01:30<00:07,  9.59it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000655/: {"detail":"Not found."}
# Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000656/: {"detail":"Not found."}
#  90%|█████████ | 657/730 [01:31<00:07,  9.84it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000657/: {"detail":"Not found."}
#  90%|█████████ | 658/730 [01:31<00:07,  9.84it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000658/: {"detail":"Not found."}
# Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000659/: {"detail":"Not found."}
#  90%|█████████ | 660/730 [01:31<00:06, 10.09it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000660/: {"detail":"Not found."}
# Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000661/: {"detail":"Not found."}
#  91%|█████████ | 662/730 [01:31<00:06, 10.23it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000662/: {"detail":"Not found."}
# Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000663/: {"detail":"Not found."}
#  91%|█████████ | 664/730 [01:31<00:06, 10.23it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000664/: {"detail":"Not found."}
# Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000665/: {"detail":"Not found."}
#  91%|█████████ | 666/730 [01:31<00:06, 10.38it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000666/: {"detail":"Not found."}
# Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000667/: {"detail":"Not found."}
#  92%|█████████▏| 668/730 [01:32<00:05, 10.44it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000668/: {"detail":"Not found."}
# Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000669/: {"detail":"Not found."}
#  92%|█████████▏| 670/730 [01:32<00:05, 10.47it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000670/: {"detail":"Not found."}
# Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000671/: {"detail":"Not found."}
#  92%|█████████▏| 672/730 [01:32<00:05, 10.50it/s]Error 404 while sending GET request to https://api.dandiarchive.org/api/dandisets/000672/: {"detail":"Not found."}
# Error 401 while sending GET request to https://api.dandiarchive.org/api/dandisets/000673/: {"detail":"Authentication credentials were not provided."}
#  92%|█████████▏| 674/730 [01:32<00:05, 10.54it/s]Error 401 while sending GET request to https://api.dandiarchive.org/api/dandisets/000675/: {"detail":"Authentication credentials were not provided."}
#  93%|█████████▎| 681/730 [01:33<00:06,  7.17it/s]Error 401 while sending GET request to https://api.dandiarchive.org/api/dandisets/000681/: {"detail":"Authentication credentials were not provided."}
#  94%|█████████▎| 684/730 [01:34<00:06,  6.87it/s]Error 401 while sending GET request to https://api.dandiarchive.org/api/dandisets/000684/: {"detail":"Authentication credentials were not provided."}
#  94%|█████████▍| 685/730 [01:34<00:05,  7.51it/s]Error 401 while sending GET request to https://api.dandiarchive.org/api/dandisets/000685/: {"detail":"Authentication credentials were not provided."}
#  95%|█████████▍| 690/730 [01:34<00:05,  7.10it/s]Error 401 while sending GET request to https://api.dandiarchive.org/api/dandisets/000690/: {"detail":"Authentication credentials were not provided."}
#  95%|█████████▌| 697/730 [01:36<00:05,  6.53it/s]Error 401 while sending GET request to https://api.dandiarchive.org/api/dandisets/000697/: {"detail":"Authentication credentials were not provided."}
# Error 401 while sending GET request to https://api.dandiarchive.org/api/dandisets/000698/: {"detail":"Authentication credentials were not provided."}
#  96%|█████████▌| 699/730 [01:36<00:03,  7.81it/s]Error 401 while sending GET request to https://api.dandiarchive.org/api/dandisets/000699/: {"detail":"Authentication credentials were not provided."}
# Error 401 while sending GET request to https://api.dandiarchive.org/api/dandisets/000700/: {"detail":"Authentication credentials were not provided."}
#  96%|█████████▌| 701/730 [01:36<00:03,  8.71it/s]Error 401 while sending GET request to https://api.dandiarchive.org/api/dandisets/000701/: {"detail":"Authentication credentials were not provided."}
# Error 401 while sending GET request to https://api.dandiarchive.org/api/dandisets/000702/: {"detail":"Authentication credentials were not provided."}
#  96%|█████████▋| 703/730 [01:36<00:02,  9.13it/s]Error 401 while sending GET request to https://api.dandiarchive.org/api/dandisets/000703/: {"detail":"Authentication credentials were not provided."}
#  96%|█████████▋| 704/730 [01:36<00:02,  9.29it/s]Error 401 while sending GET request to https://api.dandiarchive.org/api/dandisets/000704/: {"detail":"Authentication credentials were not provided."}
# Error 401 while sending GET request to https://api.dandiarchive.org/api/dandisets/000705/: {"detail":"Authentication credentials were not provided."}
#  97%|█████████▋| 706/730 [01:36<00:02,  9.56it/s]Error 401 while sending GET request to https://api.dandiarchive.org/api/dandisets/000706/: {"detail":"Authentication credentials were not provided."}
# Error 401 while sending GET request to https://api.dandiarchive.org/api/dandisets/000707/: {"detail":"Authentication credentials were not provided."}
#  97%|█████████▋| 708/730 [01:37<00:02,  9.82it/s]Error 401 while sending GET request to https://api.dandiarchive.org/api/dandisets/000708/: {"detail":"Authentication credentials were not provided."}
# Error 401 while sending GET request to https://api.dandiarchive.org/api/dandisets/000709/: {"detail":"Authentication credentials were not provided."}
#  99%|█████████▊| 720/730 [01:39<00:01,  5.58it/s]Error 401 while sending GET request to https://api.dandiarchive.org/api/dandisets/000720/: {"detail":"Authentication credentials were not provided."}
#  99%|█████████▉| 721/730 [01:39<00:01,  6.38it/s]Error 401 while sending GET request to https://api.dandiarchive.org/api/dandisets/000721/: {"detail":"Authentication credentials were not provided."}
#  99%|█████████▉| 725/730 [01:39<00:00,  6.52it/s]Error 401 while sending GET request to https://api.dandiarchive.org/api/dandisets/000725/: {"detail":"Authentication credentials were not provided."}
# 100%|█████████▉| 727/730 [01:40<00:00,  7.14it/s]Error 401 while sending GET request to https://api.dandiarchive.org/api/dandisets/000727/: {"detail":"Authentication credentials were not provided."}
# 100%|█████████▉| 729/730 [01:40<00:00,  6.65it/s]Error 401 while sending GET request to https://api.dandiarchive.org/api/dandisets/000729/: {"detail":"Authentication credentials were not provided."}
# 100%|██████████| 730/730 [01:40<00:00,  7.26it/s]

# %%
# For each dataset, take the 3 last digits of the identifier.
# Then from ../scripts/results, load dandiset-{digits}.jsonl as a json lines file via pandas.
# Deduplicate the rows by asset_id, picking the last element. Then, aggregate the results 
# via a sum and cast the results back to a dict. 
# Get all the results into a list.
file_metadata = []
for dandiset in tqdm(metadata):
    dandiset_id = dandiset["identifier"][-3:]
    try:
        df = pd.read_json(f"../scripts/results/dandiset-{dandiset_id}.jsonl", lines=True)
    except:
        continue
    df = df.drop_duplicates(subset="asset_id", keep="last")
    files = df.sum().to_dict()
    files["nfiles"] = df.shape[0]
    dandiset.update(files)
# Out:
#   0%|          | 0/220 [00:00<?, ?it/s]/tmp/ipykernel_11384/3955219908.py:15: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   files = df.sum().to_dict()
# /tmp/ipykernel_11384/3955219908.py:15: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   files = df.sum().to_dict()
# 100%|██████████| 220/220 [00:02<00:00, 94.66it/s]

# %%
openneuro_metadata = []
for dataset in Path('../scripts/results').glob('openneuro*.jsonl'):
    try:
        df = pd.read_json(dataset, lines=True)
    except:
        continue
    df = df.drop_duplicates(subset=["dataset_id", "subject"], keep="last")
    files = df.groupby(['dataset_id']).sum().reset_index()
    files['subjects'] = df.shape[0]
    files['modality'] = df.data_type.iloc[0]
    openneuro_metadata.append(files.to_dict(orient='records')[0])

df_openneuro = pd.DataFrame(openneuro_metadata)

df_openneuro['species'] = 'Homo sapiens - Human'
df_openneuro = df_openneuro.rename(columns={'dataset_id': 'identifier',
                                            'total_duration': 'recording_length'})
# Out:
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# ...
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()
# /tmp/ipykernel_11384/3425207040.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   files = df.groupby(['dataset_id']).sum().reset_index()

# %%
species_map = {'DANDI:000052': 'Unknown',
               'DANDI:000058': 'Unknown',
               'DANDI:000105': 'Unknown',
               'DANDI:000117': 'Unknown',
               'DANDI:000683': 'Unknown',
               'DANDI:000724': 'Homo sapiens - Human'}

clean_results = []

normalized_species = {
    'Macaca nemestrina': 'Macaca nemestrina - Pigtail macaque',
    'Macaca nemestrina - Pig-tailed macaque': 'Macaca nemestrina - Pigtail macaque',
    'Human': 'Homo sapiens - Human',
    'Rhesus monkey': 'Macaca mulatta - Rhesus monkey',
    'House mouse': 'Mus musculus - House mouse',
    'Rat': 'Rattus norvegicus - Norway rat',
    'Rat; norway rat; rats; brown rat': 'Rattus norvegicus - Norway rat',
    'Brown rat': 'Rattus norvegicus - Norway rat',
}

blacklist = [8, 20, 23, 26, 45, 109, 142, 209, 212, 288, 341, 489, 537]
blacklisted = [f"{x:03}" for x in blacklist]
all_species = []
for row in metadata:
    try:
        species = row['assetsSummary']['species'][0]['name']
    except (IndexError, KeyError):
        # Look in the name, description, and keywords, in that order
        if ' rat' in row['name'].lower():
            species = 'Rat'
        elif ' mouse' in row['name'].lower():
            species = 'House mouse'
        elif ' human' in row['name'].lower():
            species = 'Human'
        if row['name'].lower().startswith('rat'):
            species = 'Rat'
        elif row['name'].lower().startswith('mouse'):
            species = 'House mouse'
        elif row['name'].lower().startswith('human'):
            species = 'Human'
        elif ' rat' in row['description'].lower():
            species = 'Rat'
        elif ' mouse' in row['description'].lower():
            species = 'House mouse'
        elif ' mice' in row['description'].lower():
            species = 'House mouse'
        elif ' human' in row['description'].lower():
            species = 'Human'
        elif [kw for kw in row.get('keywords', []) if kw.lower().startswith('rat')]:
            species = 'Rat'
        elif [kw for kw in row.get('keywords', []) if kw.lower().startswith('mouse')]:
            species = 'House mouse'
        elif [kw for kw in row.get('keywords', []) if kw.lower().startswith('human')]:
            species = 'Human'
        elif 'simulation' in row['name'].lower():
            species = 'Simulation'
        elif 'test' in row['name'].lower():
            species = 'Unknown'
        elif 'stimulus' in row['name'].lower():
            species = 'Unknown'
        elif 'organoid' in row['name'].lower():
            species = 'Organoid'
        elif 'elegans' in row['name'].lower():
            species = 'Caenorhabditis elegans'
        else:
            species = species_map[row['identifier']]
    refined_species = normalized_species.get(species, species)
    recording_length = max([row.get('spike_recording_length', 0),
                            row.get('lfp_recording_length', 0),
                            row.get('ca_recording_length', 0)])
    row['recording_length'] = recording_length
    row['canonical_species'] = refined_species

    # Figure out the recording modality from context
    modalities = []
    if row.get('lfp_recording_length', 0) > 0:
        if refined_species == 'Homo sapiens - Human':
            modalities.append('iEEG')
        else:
            modalities.append('lfp')
    if row.get('nspikes', 0) > 0:
        modalities.append('spikes')
    if row.get('ca_recording_length', 0) > 0:
        modalities.append('calcium')
    if row.get('recording_type', "") == "icephys":
        modalities.append("icephys")
        
    if len(modalities) == 0:
        # Check for a clamp indicator
        if [x for x in row['assetsSummary'].get('variableMeasured', []) if 'Clamp' in x]:
            modalities.append('icephys')
        elif row['identifier'][-3:] in blacklisted:
            modalities.append("blacklisted")
        else:
            modalities.append('unknown')

    for modality in modalities:
        nframes_samples_or_spikes = 0
        if modality in ('lfp', 'iEEG'):
            nframes_samples_or_spikes = row['lfp_samples']
        elif modality == 'spikes':
            nframes_samples_or_spikes = row['nspikes']
        elif modality == 'calcium':
            nframes_samples_or_spikes = row['ca_samples']

        clean_results.append(
            {'identifier': row['identifier'],
             'species': refined_species,
             'recording_length': recording_length,
             'modality': modality,
             'nframes_samples_or_spikes': nframes_samples_or_spikes,
             'bytes': row['assetsSummary'].get("numberOfBytes", 0), 
             'subjects': row['assetsSummary'].get("numberOfSubjects", 0), 
             'files': row['assetsSummary'].get("numberOfFiles", 0), 
            }
        )

    print(row['identifier'],
          refined_species, 
          recording_length, 
          modalities, 
          row['assetsSummary'].get("numberOfBytes", 0), 
          row['assetsSummary'].get("numberOfSubjects", 0), 
          row['assetsSummary'].get("numberOfFiles", 0)
          )
    
clean_results += df_openneuro.to_dict(orient='rows')
# Out:
# DANDI:000003 Mus musculus - House mouse 3665367.9255999997 ['lfp', 'spikes'] 2559248010229 16 101
# DANDI:000004 Homo sapiens - Human 172911.3089485524 ['spikes'] 6197474020 59 87
# DANDI:000005 Mus musculus - House mouse 31132.45 ['spikes'] 46436686324 55 148
# DANDI:000006 Mus musculus - House mouse 34789.238391000006 ['spikes'] 139600500 12 53
# DANDI:000007 Mus musculus - House mouse 110743.41024337358 ['spikes'] 199439472 13 54
# DANDI:000008 Mus musculus - House mouse 0 ['blacklisted'] 11922334254 266 1328
# DANDI:000009 Mus musculus - House mouse 159106.66765316797 ['spikes'] 12919706852 31 173
# DANDI:000010 Mus musculus - House mouse 224628.36568132794 ['spikes', 'calcium'] 40006570644 23 158
# DANDI:000011 Mus musculus - House mouse 253327.97210887514 ['spikes'] 32435325542 19 92
# DANDI:000012 Homo sapiens - Human 0 ['icephys'] 487524911 4 297
# DANDI:000013 Mus musculus - House mouse 0 ['icephys'] 11408735292 23 52
# DANDI:000015 Mus musculus - House mouse 280013.2054845643 ['calcium'] 17159727736 6 210
# DANDI:000016 Mus musculus - House mouse 458.6795999999997 ['calcium'] 62572042499 4 135
# DANDI:000017 Mus musculus - House mouse 124042.50299664547 ['spikes'] 14682586049 10 39
# DANDI:000019 Homo sapiens - Human 19098.547065630737 ['iEEG'] 55585858956 4 31
# DANDI:000020 Mus musculus - House mouse 0 ['blacklisted'] 141856436428 1040 4435
# DANDI:000021 Mus musculus - House mouse 1784635.542748989 ['lfp', 'spikes'] 477562344354 32 214
# DANDI:000022 Mus musculus - House mouse 1412850.3305474508 ['lfp', 'spikes'] 374956840341 26 169
# DANDI:000023 Homo sapiens - Human 0 ['blacklisted'] 12401578899 56 318
# DANDI:000025 Rattus norvegicus - Norway rat 0 ['icephys'] 13664814 1 1
# DANDI:000026 Homo sapiens - Human 0 ['blacklisted'] 31186591312443 20 57526
# DANDI:000027 Rattus norvegicus - Norway rat 0 ['unknown'] 18792 2 1
# DANDI:000028 Mus musculus - House mouse 1500.0 ['lfp', 'spikes'] 42942229688 2 3
# DANDI:000029 Macaca mulatta - Rhesus monkey 5558.897832000002 ['spikes'] 39011902 5 9
     'species': 'Homo sapiens - Human',
     'recording_length': 98103600,
     'nframes_samples_or_spikes': 49051800000,  # Estimated at 500Hz
     'bytes': 49051800000 * 2 * 8, # Assuming 16-bit precision, 8 contacts
     'subjects': 607,
     'files': 607,
     }
)

clean_results.append(
    {'identifier': 'SWEC-ETHZ',
     'modality': 'iEEG',
     'species': 'Homo sapiens - Human',
     'recording_length': 9000000,
     'nframes_samples_or_spikes': 9000000 * 512,  # Estimated at 500Hz
     'bytes': 9000000 * 512 * 4 * 64, # Assuming 32-bit precision, 64 contacts
     'subjects': 18,
     'files': 2500,
     }
)

# %%
df = pd.DataFrame(clean_results)
df.modality = df.modality.str.lower()
df = df[~df.identifier.isin(['ds004091', 'ds004271', 'ds001607', 'ds003972', 'ds003974', 'ds003872', 'ds003988', 'ds004312'])]

to_lower = ['ds004278', 'ds004011', 'ds003343', 'ds004802', 'ds003620', 'ds004019', 
            'ds004018', 'ds003751', 'ds004151', 'ds003887', 'ds003885', 'ds002721', 
            'ds004018', 'ds003751', 'ds004043', 'ds003420', 'ds004816', 'ds004817', 
            'ds004252', 'ds003694']
idx = df.identifier.isin(to_lower)
df.loc[idx, 'recording_length'] = df.loc[idx, 'recording_length'] / 1e3

# Engage in extrapolation for ieeg, eeg, task-fmri, rs-fmri
def extrapolate(df, modality):
    """
    Extrapolate the duration of datasets with missing time information from their
    size. Find those which have a recording length which is non-zero. Run a linear 
    regression between the size and the duration of datasets, Then apply that to the 
    zero elements.
    """
    df_ = df[(df.modality == modality) & (df.recording_length != 0)]
    fit = LinearRegression(fit_intercept=False)
    fit.fit(df_.bytes.values.reshape((-1, 1)), df_.recording_length)

    idx = (df.modality == modality) & (df.recording_length == 0)
    df_ = df[idx]
    df.loc[idx, 'recording_length'] = fit.predict(df[idx].bytes.values.reshape((-1, 1)))
    return fit.coef_

extrapolate(df, 'eeg')
extrapolate(df, 'ieeg')
coef = extrapolate(df, 'task-fmri')
idx = df.modality == 'rs-fmri'
df.loc[idx, 'recording_length'] = df[idx, 'bytes'] * coef

df = df[df['modality'].isin(['calcium', 'ieeg', 'lfp', 'spikes', 'task-fmri', 'eeg', 'meg', 'rs-fmri'])]
df = df[df['species'].isin(['Drosophila melanogaster - Fruit fly', 
                           'Homo sapiens - Human', 
                           'Macaca mulatta - Rhesus monkey',
                           'Mus musculus - House mouse',
                           'Rattus norvegicus - Norway rat'])]
df.groupby(['species', 'modality']).sum()
# Out:
# /tmp/ipykernel_11384/3006512907.py:15: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['species', 'modality']).sum()
#                                                recording_length  \
# species                             modality
# Drosophila melanogaster - Fruit fly calcium        5.636158e+06
# Homo sapiens - Human                eeg            9.025890e+06
#                                     ieeg           2.141952e+08
#                                     meg            7.935412e+05
#                                     rs-fmri        7.920123e+05
#                                     spikes         3.645499e+05
#                                     task-fmri      3.428735e+07
# Macaca mulatta - Rhesus monkey      lfp            6.916494e+04
#                                     spikes         3.390446e+06
# Mus musculus - House mouse          calcium        1.157800e+07
#                                     lfp            2.452109e+07
#                                     spikes         2.726866e+07
# Rattus norvegicus - Norway rat      calcium        3.517204e+03
#                                     lfp            2.035067e+07
#                                     spikes         7.511491e+06
#
#                                                nframes_samples_or_spikes  \
# species                             modality
# Drosophila melanogaster - Fruit fly calcium                 1.600142e+07
# Homo sapiens - Human                eeg                     0.000000e+00
#                                     ieeg                    1.059444e+11
#                                     meg                     0.000000e+00
#                                     rs-fmri                 0.000000e+00
#                                     spikes                  3.441153e+07
#                                     task-fmri               0.000000e+00
# Macaca mulatta - Rhesus monkey      lfp                     1.383299e+08
#                                     spikes                  5.114969e+09
# Mus musculus - House mouse          calcium                 4.230474e+08
#                                     lfp                     1.243913e+11
#                                     spikes                  4.349478e+10
# Rattus norvegicus - Norway rat      calcium                 3.195200e+04
#                                     lfp                     1.086711e+11
#                                     spikes                  3.478522e+09
#
#                                                       bytes  subjects    files
# species                             modality
# Drosophila melanogaster - Fruit fly calcium    7.762433e+11      1347   1473.0
# Homo sapiens - Human                eeg        1.542502e+13      9888  21467.0
#                                     ieeg       5.331130e+12      2086   5645.0
#                                     meg        1.028498e+12       294   1672.0
#                                     rs-fmri    4.819255e+12      9275  38362.0
#                                     spikes     2.352781e+11       149    287.0
#                                     task-fmri  2.048482e+13     14702  95914.0
# Macaca mulatta - Rhesus monkey      lfp        1.875350e+11         2     15.0
#                                     spikes     2.901123e+11        31   2097.0
# Mus musculus - House mouse          calcium    1.460958e+13       902  11917.0
#                                     lfp        1.277396e+14       589  12479.0
#                                     spikes     1.187152e+14       956  15054.0
# Rattus norvegicus - Norway rat      calcium    8.427372e+10        10     20.0
#                                     lfp        5.058061e+13       483   2336.0
#                                     spikes     8.369884e+12       126   1189.0

# %%
df_ = df.groupby(['modality']).sum()
df_['recording_length_hours'] = df_.recording_length * (1/ 3600)
df_['equiv_tokens'] = df_.recording_length * 100
df_['terabytes'] = df_.bytes / (1024 * 1024 * 1024 * 1024)
df_[['recording_length', 'recording_length_hours', 'equiv_tokens', 'nframes_samples_or_spikes', 'terabytes', 'subjects', 'files']]
# Out:
# /tmp/ipykernel_11384/2682396447.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_ = df.groupby(['modality']).sum()
#            recording_length  recording_length_hours  equiv_tokens  \
# modality
# calcium        1.721768e+07             4782.688367  1.721768e+09
# eeg            9.025890e+06             2507.191722  9.025890e+08
# ieeg           2.141952e+08            59498.671914  2.141952e+10
# lfp            4.494092e+07            12483.589540  4.494092e+09
# meg            7.935412e+05              220.428110  7.935412e+07
# spikes         3.853515e+07            10704.208613  3.853515e+09
# task-fmri      3.428735e+07             9524.262609  3.428735e+09
#
#            nframes_samples_or_spikes   terabytes  subjects    files
# modality
# calcium                 4.390807e+08   14.069975      2259  13410.0
# eeg                     0.000000e+00   14.028972      9888  21467.0
# ieeg                    1.059444e+11    4.848635      2086   5645.0
# lfp                     2.332007e+11  162.351870      1074  14830.0
# meg                     0.000000e+00    0.935413       294   1672.0
# spikes                  5.212268e+10  116.061051      1262  18627.0
# task-fmri               0.000000e+00   18.630835     14702  95914.0
